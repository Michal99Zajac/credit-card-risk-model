# %% [markdown]
# # Data visualisation

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load CSV file into a pandas dataframe
df = pd.read_csv('../../data/reduced__credit_card_approval.csv')

# %% [markdown]
# ## CODE_GENDER

# %%
# Create a plot from the "GENDER_CODE" column
counts = df['CODE_GENDER'].value_counts(dropna=False)
counts.plot(kind='pie', labels=counts.index, autopct='%1.1f%%')

# Add a title to the plot
plt.title('Gender Distribution')

# Show the plot
plt.savefig('../../media/visualisation/CODE_GENDER__PIE.png')

# %% [markdown]
# ## FLAG_OWN_CAR

# %%
# Create a plot from the "FLAG_OWN_CAR" column
counts = df['FLAG_OWN_CAR'].value_counts(dropna=False)
counts.plot(kind='bar', x=counts.index, y=counts.values, rot=0, width=0.5, align='center')

# Add a title to the plot
plt.title('Car Ownership Distribution')

# Show the plot
plt.savefig('../../media/visualisation/FLAG_OWN_CAR__BAR.png')

# %% [markdown]
# ## FLAG_OWN_REALTY

# %%
# Create a plot from the "FLAG_OWN_REALTY" column
counts = df['FLAG_OWN_REALTY'].value_counts(dropna=False)
counts.plot(kind='pie', labels=counts.index, autopct='%1.1f%%')

# Add a title to the plot
plt.title('Property Distribution')

# Show the plot
plt.savefig('../../media/visualisation/FLAG_OWN_REALTY__PIE.png')

# %% [markdown]
# ## CNT_CHILDREN

# %%
# Create a plot from the "CNT_CHILDREN" column
counts = df['CNT_CHILDREN'].value_counts(dropna=False)
counts.plot(kind='bar', x=counts.index, y=counts.values, rot=0, width=0.5, align='center')

# Add a title to the plot
plt.title('Number of Children Distribution')

# Show the plot
plt.savefig('../../media/visualisation/CNT_CHILDREN__BAR.png')

# %% [markdown]
# ## AMT_INCOME_TOTAL

# %%
# Create a plot from the "AMT_INCOME_TOTAL" column
totals = df['AMT_INCOME_TOTAL']
totals.plot(kind='hist', bins=30)

# Add a title and x-axis label to the plot
plt.title('Distribution of Annual Income')
plt.xlabel('Annual Income')

# Show the plot
plt.savefig('../../media/visualisation/AMT_INCOME_TOTAL__HIST.png')

# %% [markdown]
# ## NAME_EDUCATION_TYPE

# %%
# Create a plot from the "NAME_EDUCATION_TYPE" column
counts = df['NAME_EDUCATION_TYPE'].value_counts(dropna=False)
ax = counts.plot(kind='pie', labels=None)

# Add a title to the plot
plt.title('Education Level Distribution')

# Calculate percentage values
percentages = (counts / counts.sum() * 100).round(2).astype(str) + '%'

# Create a list of labels with percentage values
labels_with_percentages = [f'{label} ({percentage})' for label, percentage in zip(counts.index, percentages)]

# Set the legend title and position
ax.legend(title='Education Levels', labels=labels_with_percentages, bbox_to_anchor=(0, -0.4), loc='lower left', borderaxespad=0)

# Show the plot
plt.savefig('../../media/visualisation/NAME_EDUCATION_TYPE__PIE.png')

# %% [markdown]
# ## NAME_FAMILY_STATUS

# %%
# Create a plot from the "NAME_FAMILY_STATUS" column
counts = df['NAME_FAMILY_STATUS'].value_counts(dropna=False)
counts.plot(kind='bar', x=counts.index, y=counts.values, rot=90, width=0.5, align='center')

# Add a title to the plot
plt.title('Distribution of Family Status')

# Show the plot
plt.savefig('../../media/visualisation/NAME_FAMILY_STATUS__BAR.png')

# %% [markdown]
# ## NAME_HOUSING_TYPE

# %%
# Create a plot from the "NAME_HOUSING_TYPE" column
counts = df['NAME_HOUSING_TYPE'].value_counts(dropna=False)
counts.plot(kind='bar', x=counts.index, y=counts.values, rot=90, width=0.5, align='center')

# Add a title to the plot
plt.title('Distribution of Housing Types')

# Show the plot
plt.savefig('../../media/visualisation/NAME_HOUSING_TYPE__BAR.png')

# %% [markdown]
# ## DAYS_BIRTH

# %%
# Create a plot from the "DAYS_BIRTH" column
totals = df['DAYS_BIRTH']
totals.plot(kind='hist', bins=30)

# Add a title and x-axis label to the plot
plt.title('Distribution of Age')
plt.xlabel('Age in Days')

# Show the plot
plt.savefig('../../media/visualisation/DAYS_BIRTH__HIST.png')

# %% [markdown]
# ## DAYS_EMPLOYED

# %%
# Create a plot from the "DAYS_EMPLOYED" column
totals = df['DAYS_EMPLOYED']
totals.plot(kind='hist', bins=30)

# Add a title and x-axis label to the plot
plt.title('Distribution of Employment Duration')
plt.xlabel('Duration of Employment in Days')

# Show the plot
plt.savefig('../../media/visualisation/DAYS_EMPLOYED__HIST.png')

# %% [markdown]
# ## FLAG_MOBIL

# %%
# Create a plot from the "FLAG_MOBIL" column
counts = df['FLAG_MOBIL'].value_counts(dropna=False)
counts.plot(kind='bar')

# Add a title to the plot
plt.title('Distribution of Mobile Phone Ownership')

# Show the plot
plt.savefig('../../media/visualisation/FLAG_MOBIL__BAR.png')

# %% [markdown]
# ## FLAG_WORK_PHONE

# %%
# Create a plot from the "FLAG_WORK_PHONE" column
counts = df['FLAG_WORK_PHONE'].value_counts(dropna=False)
counts.plot(kind='bar')

# Add a title to the plot
plt.title('Distribution of Work Phone Ownership')

# Show the plot
plt.savefig('../../media/visualisation/FLAG_WORK_PHONE__BAR.png')

# %% [markdown]
# ## FLAG_PHONE

# %%
# Create a plot from the "FLAG_PHONE" column
counts = df['FLAG_PHONE'].value_counts(dropna=False)
counts.plot(kind='pie', autopct='%1.1f%%')

# Add a title to the plot
plt.title('Distribution of Phone Ownership')

# Show the plot
plt.savefig('../../media/visualisation/FLAG_PHONE__PIE.png')

# %% [markdown]
# ## FLAG_EMAIL

# %%
# Create a plot from the "FLAG_EMAIL" column
counts = df['FLAG_EMAIL'].value_counts(dropna=False)
counts.plot(kind='pie', autopct='%1.1f%%')

# Add a title to the plot
plt.title('Distribution of Email Ownership')

# Show the plot
plt.savefig('../../media/visualisation/FLAG_EMAIL__PIE.png')

# %% [markdown]
# ## JOB

# %%
# Create a plot from the "JOB" column
counts = df['JOB'].value_counts(dropna=False)
counts.plot(kind='bar', x=counts.index, y=counts.values, rot=90, width=0.5, align='center')

# Add a title to the plot
plt.title('Distribution of Jobs')

# Show the plot
plt.savefig('../../media/visualisation/JOB__BAR.png')

# %% [markdown]
# ## BEGIN_MONTHS

# %%
# Create a plot from the "BEGIN_MONTHS" column
totals = df['BEGIN_MONTHS']
totals.plot(kind='hist', bins=100)

# Add a title and x-axis label to the plot
plt.title('Distribution of Loan Application Start Months')
plt.xlabel('Months Before Current Month')

# Show the plot
plt.savefig('../../media/visualisation/BEGIN_MONTHS__HIST.png')

# %% [markdown]
# ## STATUS

# %%
# Create a plot from the "STATUS" column
counts = df['STATUS'].value_counts(dropna=False)
ax = counts.plot(kind='pie', labels=None)

# Add a title to the plot
plt.title('Distribution of Loan Status')

# Calculate percentage values
percentages = (counts / counts.sum() * 100).round(2).astype(str) + '%'

# Create a list of labels with percentage values
labels_with_percentages = [f'{label} ({percentage})' for label, percentage in zip(counts.index, percentages)]

# Set the legend title and position
ax.legend(title='Loan Status', labels=labels_with_percentages, bbox_to_anchor=(0, -0.5), loc='lower left', borderaxespad=0)

# Show the plot
plt.savefig('../../media/visualisation/STATUS__PIE.png')

# %% [markdown]
# ## TARGET

# %%
# Create a plot from the "TARGET" column
counts = df['TARGET'].value_counts(dropna=False)
counts.plot(kind='bar')

# Add a title to the plot
plt.title('Distribution of Risk')

# Show the plot
plt.savefig('../../media/visualisation/TARGET__BAR.png')
